# %%
import pandas as pd

# %%
LumA = pd.read_csv(r'C:\Users\javte\Documents\SSEF project\results\round 2 boruta\rank1 only\LumA_rank1only.csv',index_col=[0])
LumB = pd.read_csv(r'C:\Users\javte\Documents\SSEF project\results\round 2 boruta\rank1 only\LumB_rank1only.csv',index_col=[0])
her2 = pd.read_csv(r'C:\Users\javte\Documents\SSEF project\results\round 2 boruta\rank1 only\her2_rank1only.csv',index_col=[0])
basal = pd.read_csv(r'C:\Users\javte\Documents\SSEF project\results\round 2 boruta\rank1 only\basal_rank1only.csv',index_col=[0])
normal = pd.read_csv(r'C:\Users\javte\Documents\SSEF project\results\round 2 boruta\rank1 only\normal_rank1only.csv',index_col=[0])

# %%
LumA
# Out:
#                   Feature  Ranking
# 12443  ENSG00000174607.11        1
# 11655  ENSG00000170153.11        1
# 11685  ENSG00000170312.16        1
# 11698   ENSG00000170369.4        1
# 11700   ENSG00000170373.8        1
# ...                   ...      ...
# 21456   ENSG00000261054.1        1
# 21453   ENSG00000261039.3        1
# 22072   ENSG00000267365.1        1
# 24173   ENSG00000283445.1        1
# 24847   ENSG00000288048.1        1
#
# [730 rows x 2 columns]

# %%
types = [LumA, LumB, her2, basal, normal]
names = ['LumA', 'LumB', 'her2', 'basal', 'normal']
for type, name in zip(types,names): 
    type_data = list(type.Feature)
    type_input = [item.split('.', 1)[0] for item in type_data]
    gprofile_input = '\n'.join(type_input)
    text_file = open(rf'C:\Users\javte\Documents\SSEF project\datasets\gprofiler_inputs\inputs_2\{name}.txt', "x")
    text_file.write(gprofile_input)
    text_file.close()

# %%
text_file = open(rf'C:\Users\javte\Documents\SSEF project\datasets\gprofiler_inputs\redo_inputs\LumA.txt','r')

# %%
data=text_file.read()
print(data,'r')
# Out:
# ENSG00000160753
# ENSG00000154678
# ENSG00000230838
# ENSG00000178662
# ENSG00000078596
# ENSG00000154493
# ENSG00000154473
# ENSG00000259683
# ENSG00000078549
# ENSG00000154263
# ENSG00000154258
# ENSG00000154134
# ENSG00000259374
# ENSG00000179270
# ENSG00000153820
# ENSG00000153291
# ENSG00000152990
# ENSG00000152580
# ENSG00000179636
# ENSG00000152465
# ENSG00000179796
# ENSG00000077616
# ENSG00000152104
# ENSG00000261039
# ENSG00000261175
# ENSG00000260219
# ENSG00000154736
# ENSG00000154856
# ENSG00000154917
# ENSG00000099953
# ENSG00000176532
# ENSG00000256508
# ENSG00000158966
# ENSG00000176533
# ENSG00000158458
# ENSG00000257743
# ENSG00000177098
# ENSG00000258311
# ENSG00000231367
# ENSG00000100034
# ENSG00000158186
# ENSG00000258479
# ENSG00000158106
# ENSG00000231290
# ENSG00000258545
# ENSG00000157368
# ENSG00000258604
# ENSG00000157303
# ENSG00000079616
# ENSG00000079462
# ENSG00000155970
# ENSG00000155886
# ENSG00000177732
# ENSG00000154928
# ENSG00000229558
# ...

# %%
LumA
# Out:
#                   Feature  Ranking
# 9720   ENSG00000160753.16        1
# 9052   ENSG00000154678.18        1
# 18005   ENSG00000230838.1        1
# 13022  ENSG00000178662.16        1
# 1369   ENSG00000078596.11        1
# ...                   ...      ...
# 13739   ENSG00000183682.8        1
# 6992   ENSG00000137731.14        1
# 7332    ENSG00000139874.6        1
# 6511   ENSG00000135046.14        1
# 6226   ENSG00000132970.14        1
#
# [395 rows x 2 columns]
