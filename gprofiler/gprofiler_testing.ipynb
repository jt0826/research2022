# %%
pip install gprofiler-official
# Out:
# Requirement already satisfied: gprofiler-official in /home/bpm_javier/anaconda3/lib/python3.9/site-packages (1.0.0)
# Requirement already satisfied: requests in /home/bpm_javier/anaconda3/lib/python3.9/site-packages (from gprofiler-official) (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/bpm_javier/anaconda3/lib/python3.9/site-packages (from requests->gprofiler-official) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/bpm_javier/anaconda3/lib/python3.9/site-packages (from requests->gprofiler-official) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/bpm_javier/anaconda3/lib/python3.9/site-packages (from requests->gprofiler-official) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/bpm_javier/anaconda3/lib/python3.9/site-packages (from requests->gprofiler-official) (2022.9.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
from gprofiler import gprofiler
import pandas as pd
import requests

# %%
from gprofiler import GProfiler

gp = GProfiler(return_dataframe=True)
gp.profile(organism='hsapiens',
            query=['NR1H4','TRIP12','UBC','FCRL3','PLXNA3','GDNF','VPS11'])
# Out:
#   source      native                                         name   p_value  \
# 0  GO:BP  GO:0048486   parasympathetic nervous system development  0.015328
# 1  GO:BP  GO:0034162       toll-like receptor 9 signaling pathway  0.019029
# 2  GO:BP  GO:0048585  negative regulation of response to stimulus  0.049588
# 3  GO:MF  GO:1902122                chenodeoxycholic acid binding  0.049873
# 4  CORUM  CORUM:5669                        PlexinA3-Nrp1 complex  0.049987
# 5  CORUM  CORUM:5759                        PLXNA3-RANBPM complex  0.049987
#
#    significant                                        description  term_size  \
# 0         True  "The process whose specific outcome is the pro...         18
# 1         True  "The series of molecular signals initiated by ...         20
# 2         True  "Any process that stops, prevents, or reduces ...       1604
# 3         True  "Binding to chenodeoxycholic acid." [GOC:bf, G...          1
# 4         True                              PlexinA3-Nrp1 complex          2
# 5         True                              PLXNA3-RANBPM complex          2
#
#    query_size  intersection_size  effective_domain_size  precision    recall  \
# 0           7                  2                  21092   0.285714  0.111111
# 1           7                  2                  21092   0.285714  0.100000
# 2           7                  5                  21092   0.714286  0.003117
# 3           7                  1                  20166   0.142857  1.000000
# 4           1                  1                   3385   1.000000  0.500000
# 5           1                  1                   3385   1.000000  0.500000
#
#      query                               parents
# 0  query_1              [GO:0048483, GO:0048731]
# 1  query_1                          [GO:0002224]
# 2  query_1  [GO:0048519, GO:0048583, GO:0050896]
# 3  query_1  [GO:0005496, GO:0032052, GO:0043177]
# 4  query_1                       [CORUM:0000000]
# 5  query_1                       [CORUM:0000000]
