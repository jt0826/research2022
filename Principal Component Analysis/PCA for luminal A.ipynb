# %%
import pandas as pd
import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
#transpose matrix to have sample as row, gene in column
LumA_transpose = pd.read_csv(r'C:\Users\javte\Documents\SSEF project\datasets\gene expression+metadata\LumA_NT_logCPMrmBatch_20221128.csv', index_col=[0])
LumA = LumA_transpose.transpose()
LumA.head()
# Out:
#                               ENSG00000000003.15  ENSG00000000005.6  \
# TCGA-AC-A8OP-01A-11R-A36F-07            4.102683          -0.264710
# TCGA-D8-A1XU-01A-11R-A14M-07            6.665188          -2.768219
# TCGA-BH-A18L-11A-42R-A12D-07            6.207314           5.266865
# TCGA-BH-A0B1-01A-12R-A056-07            6.008083          -2.925248
# TCGA-3C-AAAU-01A-11R-A41B-07            3.600208          -3.269989
#
#                               ENSG00000000419.13  ENSG00000000457.14  \
# TCGA-AC-A8OP-01A-11R-A36F-07            5.295867            4.722433
# TCGA-D8-A1XU-01A-11R-A14M-07            5.714447            4.453470
# TCGA-BH-A18L-11A-42R-A12D-07            4.878837            4.308785
# TCGA-BH-A0B1-01A-12R-A056-07            5.258046            4.925308
# TCGA-3C-AAAU-01A-11R-A41B-07            5.223848            4.188995
#
#                               ENSG00000000460.17  ENSG00000000938.13  \
# ...

# %%
#PCA
pca = PCA(n_components=50)
principalComponents_LumA = pca.fit_transform(LumA)
principal_LumA_Df = pd.DataFrame(data = principalComponents_LumA
             , columns = ["PC"+str(i) for i in range(1, 51)])

# %%
principal_LumA_Df.head()
# Out:
#           PC1        PC2        PC3        PC4        PC5        PC6  \
# 0  -34.756513  -3.897099  -3.866967 -37.878473  23.302470  27.181278
# 1  -39.140790 -15.578549 -19.478732   3.703368   1.989463  -4.780741
# 2  141.021287  24.722809  15.153526   9.227828  -1.213893   1.005873
# 3  -28.016296  -7.519097   5.767009  -4.948354 -13.112141  17.449384
# 4  -74.999728  56.568584 -12.983968 -41.982582  52.447397  15.198100
#
#          PC7        PC8        PC9       PC10  ...       PC41      PC42  \
# 0  -2.119841  19.179641  -3.835505  -2.736178  ... -12.194651  1.855330
# 1  -5.966284  27.736220 -17.946523  30.352198  ...  26.915836 -9.582647
# 2  -0.140307   7.004250  -7.869418  29.316500  ...   4.294417  1.041090
# 3 -15.706518  19.766514  -5.308995 -18.779404  ... -14.247980  5.225195
# 4 -37.483456   8.330570  18.272104  42.816599  ...   1.998489 -4.419306
#
#         PC43       PC44       PC45      PC46       PC47       PC48       PC49  \
# ...

# %%
# Take pam50 column from metadata and set as index of PCA dataframe
LumA_metadata = pd.read_csv(r"C:\Users\javte\Documents\SSEF project\datasets\gene expression+metadata\LumA_NT_metadat_20221128.csv")
LumA_pam50 = LumA_metadata[('pam50')].to_list()
principal_LumA_Df['pam50'] = LumA_pam50
principal_LumA_Df.set_index('pam50', drop = True, inplace = True)
principal_LumA_Df.head()
# Out:
#                 PC1        PC2        PC3        PC4        PC5        PC6  \
# pam50
# LumA     -34.756513  -3.897099  -3.866967 -37.878473  23.302470  27.181278
# LumA     -39.140790 -15.578549 -19.478732   3.703368   1.989463  -4.780741
# Healthy  141.021287  24.722809  15.153526   9.227828  -1.213893   1.005873
# LumA     -28.016296  -7.519097   5.767009  -4.948354 -13.112141  17.449384
# LumA     -74.999728  56.568584 -12.983968 -41.982582  52.447397  15.198100
#
#                PC7        PC8        PC9       PC10  ...       PC41      PC42  \
# pam50                                                ...
# LumA     -2.119841  19.179641  -3.835505  -2.736178  ... -12.194651  1.855330
# LumA     -5.966284  27.736220 -17.946523  30.352198  ...  26.915836 -9.582647
# Healthy  -0.140307   7.004250  -7.869418  29.316500  ...   4.294417  1.041090
# LumA    -15.706518  19.766514  -5.308995 -18.779404  ... -14.247980  5.225195
# ...

# %%
#formatting plot
plt.figure()
plt.figure(figsize=(10,10))
plt.xticks(fontsize=12)
plt.yticks(fontsize=14)
plt.xlabel('PC1',fontsize=20)
plt.ylabel('PC2',fontsize=20)
plt.title("LumA PCA",fontsize=20)
targets = ['Healthy', 'LumA']
colours = ['r', 'g']
#colour code points according to pam50
for target, colour in zip(targets,colours):
    index = principal_LumA_Df.index == target
    plt.scatter(principal_LumA_Df.loc[index, 'PC1']
               , principal_LumA_Df.loc[index, 'PC2'], c = colour, s = 50)
#plot legend
plt.legend(targets,prop={'size': 15})

# %%
import matplotlib.pyplot as plt
#no. of PCs to be visualised
n = 10
plt.bar(x=principal_LumA_Df.columns[:n], height = 100*pca.explained_variance_ratio_[:n])
cumulative = np.cumsum(100*pca.explained_variance_ratio_[:n])
plt.plot(principal_LumA_Df.columns[:n], cumulative)
cumulative = np.cumsum(pca.explained_variance_ratio_[:n])
plt.xlabel('principal component')
plt.ylabel('explained variance (%)')
plt.legend(['cumulative'],prop={'size': 10},loc='best')
